# %%
import pandas as pd

def clean(file_path, out_file):
    '''
    Data cleaning pipeline:
    Renaming columns and rearranging column orders
    Converting 'date' column into a datetime object
    Adding 'day_of_the_week' classifier
    Removing unneccessary columns
    '''
    names = ['c_a', 'unit', 'scp', 'station', 'linename', 'division', 
             'date', 'time', 'desc', 'entries', 'exits']
    df = pd.read_csv(file_path, names=names, skiprows=1)
    df['date'] = pd.to_datetime(df['date'])
    df['day_of_week'] = df['date'].dt.day_name()
    df = df[['station', 'unit', 'c_a', 'scp', 'date', 'day_of_week', 'time', 'entries', 'exits']]
    #return df
    return df.to_pickle(out_file)

# %%
clean('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200627.txt', '200627')

# %%
df = pd.read_pickle('200627')
df
# Out:
#               station  unit    c_a       scp       date day_of_week      time  \
# 0               59 ST  R051   A002  02-00-00 2020-06-20    Saturday  00:00:00
# 1               59 ST  R051   A002  02-00-00 2020-06-20    Saturday  04:00:00
# 2               59 ST  R051   A002  02-00-00 2020-06-20    Saturday  08:00:00
# 3               59 ST  R051   A002  02-00-00 2020-06-20    Saturday  12:00:00
# 4               59 ST  R051   A002  02-00-00 2020-06-20    Saturday  16:00:00
# ...               ...   ...    ...       ...        ...         ...       ...
# 206666  RIT-ROOSEVELT  R469  TRAM2  00-05-01 2020-06-26      Friday  05:00:00
# 206667  RIT-ROOSEVELT  R469  TRAM2  00-05-01 2020-06-26      Friday  09:00:00
# 206668  RIT-ROOSEVELT  R469  TRAM2  00-05-01 2020-06-26      Friday  13:00:00
# 206669  RIT-ROOSEVELT  R469  TRAM2  00-05-01 2020-06-26      Friday  17:00:00
# 206670  RIT-ROOSEVELT  R469  TRAM2  00-05-01 2020-06-26      Friday  21:00:00
#
#         entries    exits
# 0       7424218  2522558
# 1       7424220  2522559
# 2       7424231  2522572
# 3       7424265  2522590
# 4       7424340  2522604
# ...         ...      ...
# 206666     5554      514
# 206667     5554      514
# 206668     5554      514
# 206669     5554      514
# 206670     5554      514
#
# [206671 rows x 9 columns]

# %%
#I only want data  from one day
df1 = df[df.date=='2020-06-20']

# %%
df2 = df1[df.scp=='02-00-00']
df2
# Out:
# <ipython-input-96-4f6cd009228b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df1[df.scp=='02-00-00']
#                 station  unit   c_a       scp       date day_of_week  \
# 0                 59 ST  R051  A002  02-00-00 2020-06-20    Saturday
# 1                 59 ST  R051  A002  02-00-00 2020-06-20    Saturday
# 2                 59 ST  R051  A002  02-00-00 2020-06-20    Saturday
# 3                 59 ST  R051  A002  02-00-00 2020-06-20    Saturday
# 4                 59 ST  R051  A002  02-00-00 2020-06-20    Saturday
# ...                 ...   ...   ...       ...        ...         ...
# 203860  FLATBUSH AV-B.C  R110  R647  02-00-00 2020-06-20    Saturday
# 203861  FLATBUSH AV-B.C  R110  R647  02-00-00 2020-06-20    Saturday
# 203862  FLATBUSH AV-B.C  R110  R647  02-00-00 2020-06-20    Saturday
# 203863  FLATBUSH AV-B.C  R110  R647  02-00-00 2020-06-20    Saturday
# 203864  FLATBUSH AV-B.C  R110  R647  02-00-00 2020-06-20    Saturday
#
#             time  entries    exits
# 0       00:00:00  7424218  2522558
# 1       04:00:00  7424220  2522559
# 2       08:00:00  7424231  2522572
# 3       12:00:00  7424265  2522590
# 4       16:00:00  7424340  2522604
# ...          ...      ...      ...
# 203860  05:00:00  8912630  3093077
# 203861  09:00:00  8912646  3093093
# 203862  13:00:00  8912677  3093128
# 203863  17:00:00  8912719  3093170
# 203864  21:00:00  8912737  3093200
#
# [263 rows x 9 columns]

# %%
df3 = df2[df.unit == 'R051']
df3
# Out:
# <ipython-input-97-d1dc79c50952>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = df2[df.unit == 'R051']
#   station  unit   c_a       scp       date day_of_week      time  entries  \
# 0   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  00:00:00  7424218
# 1   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  04:00:00  7424220
# 2   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  08:00:00  7424231
# 3   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  12:00:00  7424265
# 4   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  16:00:00  7424340
# 5   59 ST  R051  A002  02-00-00 2020-06-20    Saturday  20:00:00  7424415
#
#      exits
# 0  2522558
# 1  2522559
# 2  2522572
# 3  2522590
# 4  2522604
# 5  2522612

# %%
df_pivot = pd.pivot_table(df, index=['station', 'unit', 'c_a', 'scp', 'date', 'day_of_week', 'time'], values=['entries', 'exits'])
df_pivot.head(20)
# Out:
#                                                              entries     exits
# station unit c_a  scp      date       day_of_week time
# 1 AV    R248 H007 00-00-00 2020-06-20 Saturday    00:00:00  15455553  17299983
#                                                   04:00:00  15455553  17299994
#                                                   08:00:00  15455553  17300070
#                                                   12:00:00  15455553  17300203
#                                                   16:00:00  15455553  17300341
#                                                   20:00:00  15455553  17300434
#                            2020-06-21 Sunday      00:00:00  15455553  17300504
#                                                   04:00:00  15455553  17300514
#                                                   08:00:00  15455553  17300565
#                                                   12:00:00  15455553  17300634
#                                                   16:00:00  15455553  17300758
#                                                   20:00:00  15455553  17300844
#                            2020-06-22 Monday      00:00:00  15455553  17300917
#                                                   04:00:00  15455553  17300921
#                                                   08:00:00  15455553  17301186
#                                                   12:00:00  15455553  17301451
#                                                   16:00:00  15455553  17301647
#                                                   20:00:00  15455553  17301754
#                            2020-06-23 Tuesday     00:00:00  15455553  17301822
#                                                   04:00:00  15455553  17301830

# %%
df_pivot[:6].diff()
# Out:
#                                                             entries  exits
# station unit c_a  scp      date       day_of_week time
# 1 AV    R248 H007 00-00-00 2020-06-20 Saturday    00:00:00      NaN    NaN
#                                                   04:00:00      0.0   11.0
#                                                   08:00:00      0.0   76.0
#                                                   12:00:00      0.0  133.0
#                                                   16:00:00      0.0  138.0
#                                                   20:00:00      0.0   93.0

# %%
df_pivot[-6:].diff()
# Out:
#                                                             entries  exits
# station unit c_a  scp      date       day_of_week time
# 59 ST   R051 A002 02-00-00 2020-06-20 Saturday    00:00:00      NaN    NaN
#                                                   04:00:00      2.0    1.0
#                                                   08:00:00     11.0   13.0
#                                                   12:00:00     34.0   18.0
#                                                   16:00:00     75.0   14.0
#                                                   20:00:00     75.0    8.0

# %%
df_pivot = pd.pivot_table(df, index=['station', 'unit', 'c_a', 'scp', 'date', 'day_of_week', 'time'], values=['entries', 'exits'])
df_pivot.head()
# Out:
#                                                              entries     exits
# station unit c_a  scp      date       day_of_week time
# 1 AV    R248 H007 00-00-00 2020-06-20 Saturday    00:00:00  15455553  17299983
#                                                   04:00:00  15455553  17299994
#                                                   08:00:00  15455553  17300070
#                                                   12:00:00  15455553  17300203
#                                                   16:00:00  15455553  17300341

# %%
df['day_of_week'] = pd.to_datetime(df['date']).dt.day_name()
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#             ...
# 206666      Friday
# 206667      Friday
# 206668      Friday
# 206669      Friday
# 206670      Friday
# Name: date, Length: 206671, dtype: object

# %%
df3[:6].groupby(['station', 'unit', 'c_a', 'date', 'day_of_week', 'time', 'scp'])['entries'].diff()
# Out:
# 31952   NaN
# 31953   NaN
# 31954   NaN
# 31955   NaN
# 31956   NaN
# 31957   NaN
# Name: entries, dtype: float64
