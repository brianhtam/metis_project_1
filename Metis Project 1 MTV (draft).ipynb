# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200627.txt')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206671 entries, 0 to 206670
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   206671 non-null  object
#  1   UNIT                                                                  206671 non-null  object
#  2   SCP                                                                   206671 non-null  object
#  3   STATION                                                               206671 non-null  object
#  4   LINENAME                                                              206671 non-null  object
#  5   DIVISION                                                              206671 non-null  object
# ...

# %%
df.head(50)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/20/2020  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/21/2020  20:00:00
# ...

# %%
.rename(columns = {'C/A':'c_a', 'UNIT': 'unit', 'SCP': 'scp', 
                   'STATION':'station'})
df_grouped.head(30)
# Out:
#   File "<ipython-input-5-bec4e342f2ae>", line 1
#     .rename(columns = {'C/A':'c_a', 'UNIT': 'unit', 'SCP': 'scp',
#     ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.TIME
# Out:
# 0         00:00:00
# 1         04:00:00
# 2         08:00:00
# 3         12:00:00
# 4         16:00:00
#             ...
# 206666    05:00:00
# 206667    09:00:00
# 206668    13:00:00
# 206669    17:00:00
# 206670    21:00:00
# Name: TIME, Length: 206671, dtype: object

# %%
df.TIME
# Out:
# 0         00:00:00
# 1         04:00:00
# 2         08:00:00
# 3         12:00:00
# 4         16:00:00
#             ...
# 206666    05:00:00
# 206667    09:00:00
# 206668    13:00:00
# 206669    17:00:00
# 206670    21:00:00
# Name: TIME, Length: 206671, dtype: object

# %%
date = df.DATE

# %%
def my_func(x):
    return x.split('/')
srd_unique = df['DATE'].apply(my_func).unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b91f11f83942> in <module>
#       1 def my_func(x):
#       2     return x.split('/')
# ----> 3 srd_unique = df[('DATE')].apply(my_func).unique()
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# ...

# %%
df.DATE.str.strip('/')
# Out:
# 0         06/20/2020
# 1         06/20/2020
# 2         06/20/2020
# 3         06/20/2020
# 4         06/20/2020
#              ...
# 206666    06/26/2020
# 206667    06/26/2020
# 206668    06/26/2020
# 206669    06/26/2020
# 206670    06/26/2020
# Name: DATE, Length: 206671, dtype: object

# %%
df['date_working'] = df['DATE'].str.replace(r'/', '')

# %%
df['data_working']
# Out:
# 0         06202020
# 1         06202020
# 2         06202020
# 3         06202020
# 4         06202020
#             ...
# 206666    06262020
# 206667    06262020
# 206668    06262020
# 206669    06262020
# 206670    06262020
# Name: DATE, Length: 206671, dtype: object

# %%
df['time_working']=df['TIME'].str.replace(r':','')

# %%
df['time_working']
# Out:
# 0         000000
# 1         040000
# 2         080000
# 3         120000
# 4         160000
#            ...
# 206666    050000
# 206667    090000
# 206668    130000
# 206669    170000
# 206670    210000
# Name: time_working, Length: 206671, dtype: object

# %%
df['time_index'] = df['date_working'] + df['time_working']
df['time_index']
# Out:
# 0         06202020000000
# 1         06202020040000
# 2         06202020080000
# 3         06202020120000
# 4         06202020160000
#                ...
# 206666    06262020050000
# 206667    06262020090000
# 206668    06262020130000
# 206669    06262020170000
# 206670    06262020210000
# Name: time_index, Length: 206671, dtype: object
